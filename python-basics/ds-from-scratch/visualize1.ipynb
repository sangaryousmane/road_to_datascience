# %%
from matplotlib import pyplot as plt

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='g', marker='o', linestyle='solid');
plt.title("Nominal GDP")
plt.ylabel("Billion $")
plt.xlabel("Year ");

# %%
# Bar char
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# xs = [i + 0.1 for i, _ in enumerate(movies)]
plt.bar(movies, num_oscars)
plt.title("Number of academy awards: ")

plt.xlabel("Movies ")
plt.ylabel("Number of Oscars")
plt.xticks([x + 0.5 for x, _ in enumerate(movies)], movies)
# Out:
# ([<matplotlib.axis.XTick at 0x1c7e68ae080>,
# ...
#  [Text(0.5, 0, 'Annie Hall'),
#   Text(1.5, 0, 'Ben-Hur'),
#   Text(2.5, 0, 'Casablanca'),
#   Text(3.5, 0, 'Gandhi'),
#   Text(4.5, 0, 'West Side Story')])

# %%
# Line charts
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

# Legend, x-label, title and show
plt.legend(loc=9)  # Loc 9 means top center
plt.xlabel('Model Complexity')
plt.title("The Bias-variance Tradeoff")
plt.figure(figsize=(17, 7))

# %%
"""
A scatter plot is the right choice for visualizing the relationship between two paired
sets of data. For example, Figure 3-7 illustrates the relationship between the number
of friends your users have and the number of minutes they spend on the site every
day:
"""
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend, minute in zip(labels, friends, minutes):
    plt.annotate(label, xy=(friend, minute),
                 xytext=(5, -5),
                 textcoords='offset points')

plt.title("Daily minutes vs Number of friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the sites")
# Out:
# Text(0, 0.5, 'daily minutes spent on the sites')

# %%
# Statistics
from collections import Counter


def data_range(x):
    return max(x) - min(x)

data_range([3, 4, 1, 5])
# Out:
# 4
